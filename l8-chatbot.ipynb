# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

api_key = os.getenv("GROQ_API_KEY")

if not api_key:
    raise ValueError("API key not found. Make sure to set GROQ_API_KEY in your .env file.")

from groq import Groq

client = Groq(api_key=api_key)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama3-8b-8192",
)
print(chat_completion)
print(chat_completion.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-fe8bca39-b3c6-4ed5-b73e-8389952ee47b', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Fast language models have become increasingly important in recent years due to several reasons. Here are some of the key aspects:\n\n1. **Efficiently processing large amounts of data**: Fast language models can process large amounts of text data quickly, which is essential for tasks like natural language processing, sentiment analysis, and topic modeling. They can handle big datasets, making it possible to analyze and generate text in a timely manner.\n2. **Real-time applications**: Fast language models are crucial for real-time applications like chatbots, virtual assistants, and language translation software. They enable instant responses to user queries, making interactions more seamless and efficient.\n3. **Scalability**: As data grows exponentially, fast language models can scale to process larger amounts of data, ensuring that the models remain accurate and responsive even with a massive influx of new text.\n4. **Competing with humans**: Fast language models can generate text quickly, potentially competing with human writers in certain tasks. This has implications for content creation, journalism, and even creative writing.\n5. **Research and development**: Fast language models are essential for researchers and developers to experiment with new ideas and techniques, enabling them to iterate and refine their models more quickly.\n6. **Edge AI and IoT**: Fast language models can be deployed on edge devices, enabling AI-powered language processing on devices with limited computing resources, such as wearables, smart home devices, and autonomous vehicles.\n7. **Cost savings**: Training and deploying fast language models can be more cost-effective than traditional modeling methods, as they require less computational resources and time.\n8. **Improved user experiences**: Fast language models can be used to enhance user experiences by providing instant responses, personalized recommendations, and accurate language translation.\n9. **Time-sensitive applications**: Fast language models are critical for applications with strict time constraints, such as:\n\t* Live event coverage: Fast language models can generate real-time event summaries, updates, and insights.\n\t* Crisis response: Models can analyze crisis-related text data quickly to provide critical information and support emergency responders.\n\t* Financial analysis: Models can process financial news and data rapidly to provide timely insights and market analysis.\n10. **Advancements in NLP**: The development of fast language models is a critical step towards expanding the capabilities of natural language processing (NLP) and enabling more sophisticated language understanding and generation.\n\nOverall, fast language models have the potential to transform various industries and applications, enabling faster, more accurate, and more efficient language processing and generation.', role='assistant', function_call=None, tool_calls=None))], created=1730603347, model='llama3-8b-8192', object='chat.completion', system_fingerprint='fp_a97cfe35ae', usage=CompletionUsage(completion_tokens=501, prompt_tokens=18, total_tokens=519, completion_time=0.4175, prompt_time=0.002580836, queue_time=0.010772293, total_time=0.420080836), x_groq={'id': 'req_01jbqzyvv8e5g894s5a1x7wga1'})
# Fast language models have become increasingly important in recent years due to several reasons. Here are some of the key aspects:
#
# 1. **Efficiently processing large amounts of data**: Fast language models can process large amounts of text data quickly, which is essential for tasks like natural language processing, sentiment analysis, and topic modeling. They can handle big datasets, making it possible to analyze and generate text in a timely manner.
# 2. **Real-time applications**: Fast language models are crucial for real-time applications like chatbots, virtual assistants, and language translation software. They enable instant responses to user queries, making interactions more seamless and efficient.
# 3. **Scalability**: As data grows exponentially, fast language models can scale to process larger amounts of data, ensuring that the models remain accurate and responsive even with a massive influx of new text.
# 4. **Competing with humans**: Fast language models can generate text quickly, potentially competing with human writers in certain tasks. This has implications for content creation, journalism, and even creative writing.
# 5. **Research and development**: Fast language models are essential for researchers and developers to experiment with new ideas and techniques, enabling them to iterate and refine their models more quickly.
# 6. **Edge AI and IoT**: Fast language models can be deployed on edge devices, enabling AI-powered language processing on devices with limited computing resources, such as wearables, smart home devices, and autonomous vehicles.
# 7. **Cost savings**: Training and deploying fast language models can be more cost-effective than traditional modeling methods, as they require less computational resources and time.
# 8. **Improved user experiences**: Fast language models can be used to enhance user experiences by providing instant responses, personalized recommendations, and accurate language translation.
# 9. **Time-sensitive applications**: Fast language models are critical for applications with strict time constraints, such as:
# 	* Live event coverage: Fast language models can generate real-time event summaries, updates, and insights.
# 	* Crisis response: Models can analyze crisis-related text data quickly to provide critical information and support emergency responders.
# 	* Financial analysis: Models can process financial news and data rapidly to provide timely insights and market analysis.
# 10. **Advancements in NLP**: The development of fast language models is a critical step towards expanding the capabilities of natural language processing (NLP) and enabling more sophisticated language understanding and generation.
#
# Overall, fast language models have the potential to transform various industries and applications, enabling faster, more accurate, and more efficient language processing and generation.

# %%
def get_completion_from_messages(messages, model="llama3-8b-8192", temperature=0):
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message.content

# %%
messages =  [  
{'role':'system', 'content':'You are an assistant that speaks like Shakespeare.'},    
{'role':'user', 'content':'tell me a joke'},   
{'role':'assistant', 'content':'Why did the chicken cross the road'},   
{'role':'user', 'content':'I don\'t know'}  ]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Good sir or madam, thou dost find thyself perplexed by the riddle of the ages! Fear not, for I shall reveal the answer unto thee. 'Tis thus: To get to the... (dramatic pause) ...other side! (thunderous laughter) Hark! Didst thou not find that most diverting?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Hi, my name is Isa'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Nice to meet you, Isa! I'm a friendly chatbot, and I'm happy to chat with you. How's your day going so far?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Yes,  can you remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm happy to help! However, I'm a new chatbot, and I don't have any information about you or your name. Each time you interact with me, it's a brand new conversation, and I don't retain any information from previous chats. Would you like to tell me your name, or is there something else I can help you with?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Isa'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I remember! Your name is Isa!

# %% [markdown]
# # OrderBot
# We can automate the collection of user prompts and assistant responses to build a  OrderBot. The OrderBot will take orders at a pizza restaurant.

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
For common item such as ice and napkin ect., you should always add them to the order if customers ask (if they didn't ask for too much). \
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b56dc8c6-be47-44aa-bd18-9d8b9ec51d07'>
#   <div id="b72b2e34-52b0-4df2-8394-0c717cc501a9" data-root-id="b56dc8c6-be47-44aa-bd18-9d8b9ec51d07" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"71aa57c3-a0c4-46c5-81b5-2203eedaf186":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b56dc8c6-be47-44aa-bd18-9d8b9ec51d07"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"61b474f8-c688-4346-ad3b-6223c2f334b8","attributes":{"plot_id":"b56dc8c6-be47-44aa-bd18-9d8b9ec51d07","comm_id":"0cf2dbdc86dd4916afaebd0daf0bcfc1","client_comm_id":"4c094ff2f1fc470fa91a16173a0801ce"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"71aa57c3-a0c4-46c5-81b5-2203eedaf186","roots":{"b56dc8c6-be47-44aa-bd18-9d8b9ec51d07":"b72b2e34-52b0-4df2-8394-0c717cc501a9"},"root_ids":["b56dc8c6-be47-44aa-bd18-9d8b9ec51d07"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Column
#     [0] TextInput(placeholder='Enter text here…')
#     [1] Row
#         [0] Button(name='Chat!')
#     [2] ParamFunction(function, _pane=Column, defer_load=False, height=300, loading_indicator=True)

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
